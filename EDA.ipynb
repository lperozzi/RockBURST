# %%
# %load_ext watermark
# %watermark -d -v -m -p pandas
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# 2017-05-08
#
# CPython 3.5.2
# IPython 5.1.0
#
# pandas 0.18.1
#
# compiler   : GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)
# system     : Darwin
# release    : 16.5.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit

# %%
import pandas as pd
import glob

# %% [markdown]
# ## Read Microseismicity events

# %%
path ='../data/microseismic_and_blasting_2009_2016/' # use your path
allEvents = glob.glob(path + "/*events.csv")
allBlasts = glob.glob(path + "/*blasts.csv")

frameEvents = pd.DataFrame()
list_ = []
for file_ in allEvents:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frameEvents = pd.concat(list_)

frameBlasts = pd.DataFrame()
list_ = []
for file in allBlasts:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frameBlasts = pd.concat(list_)

frames = [frameEvents,frameBlasts]
frame = pd.concat(frames)

# %%
frame.describe(include='all')
# Out:
# /Users/lorenzoperozzi/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Date(y/m/d) Time(H:M:S)      MilliSec     Type      Northing  \
# count      1966219     1966219  1.966219e+06  1966219  1.966219e+06
# unique        2894       86036           NaN        4           NaN
# top     2016/06/30    18:15:35           NaN        n           NaN
# freq         24408         168           NaN  1185824           NaN
# mean           NaN         NaN  4.974015e+02      NaN  1.015213e+04
# std            NaN         NaN  2.878352e+02      NaN  9.502840e+01
# min            NaN         NaN  0.000000e+00      NaN  9.696570e+03
# 25%            NaN         NaN  2.480000e+02      NaN  1.005536e+04
# 50%            NaN         NaN  4.970000e+02      NaN  1.014573e+04
# 75%            NaN         NaN  7.450000e+02      NaN  1.022091e+04
# max            NaN         NaN  9.990000e+02      NaN  1.054154e+04
#
#              Easting         Depth        NN_Err        EE_Err        DD_Err  \
# count   1.966219e+06  1.966219e+06  1.966219e+06  1.966219e+06  1.966219e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    1.024549e+04  2.926476e+03  3.053897e+00  2.342115e+00  2.714587e+00
# std     6.996766e+01  1.262756e+02  5.230277e+00  3.540760e+00  3.606952e+00
# min     9.652960e+03  2.470060e+03  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     1.021941e+04  2.856150e+03  1.710000e+00  1.260000e+00  1.390000e+00
# 50%     1.024129e+04  2.922040e+03  2.200000e+00  1.680000e+00  1.930000e+00
# 75%     1.029448e+04  2.995240e+03  3.200000e+00  2.540000e+00  2.990000e+00
# max     1.077188e+04  3.289090e+03  9.999000e+02  9.999000e+02  9.999000e+02
#
#            ...              Es/Ep      SourceRo     AspRadius      StaticSD  \
# count      ...       1.966219e+06  1.966219e+06  1.966219e+06  1.966219e+06
# unique     ...                NaN           NaN           NaN           NaN
# top        ...                NaN           NaN           NaN           NaN
# freq       ...                NaN           NaN           NaN           NaN
# mean       ...       8.328034e+00  2.450218e+00  7.472474e-01  4.021229e+05
# std        ...       7.415460e+00  1.717213e+00  4.506218e-01  1.686472e+06
# min        ...       0.000000e+00  2.400000e-01  0.000000e+00  1.264000e+01
# 25%        ...       4.760000e+00  1.350000e+00  5.300000e-01  8.039893e+04
# 50%        ...       7.030000e+00  1.960000e+00  6.300000e-01  1.799541e+05
# 75%        ...       1.020000e+01  2.930000e+00  8.000000e-01  4.144970e+05
# max        ...       9.990000e+02  1.940600e+02  4.071000e+01  1.321172e+09
#
#            AppStress     DyStressD     MaxDispla    PeakVelPar    PeakAccPar  \
# count   1.966219e+06  1.966219e+06  1.966219e+06  1.966219e+06  1.966219e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.138633e+04  6.274758e+05  1.240960e-06  2.927349e-03  4.878235e+04
# std     4.861310e+05  7.139087e+05  1.210201e-04  2.161058e-02  4.511883e+04
# min     3.880000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     4.432195e+03  2.638285e+05  0.000000e+00  0.000000e+00  2.126724e+04
# 50%     9.880170e+03  4.371056e+05  0.000000e+00  0.000000e+00  3.626662e+04
# 75%     2.270628e+04  7.574970e+05  0.000000e+00  0.000000e+00  6.146187e+04
# max     6.725621e+08  2.651873e+07  3.000000e-02  4.130000e+00  1.610532e+06
#
#         Unnamed: 24
# count           0.0
# unique          NaN
# top             NaN
# freq            NaN
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
#
# [11 rows x 25 columns]

# %%
ls ../data/microseismic_and_blasting_2009_2016/
# Out:
# ../data/microseismic and blasting 2009-2016/2016events.csv*
